# %%
Q].Naive Bayes Classifier 

ANS :- there is an hint like 2-3 words or any kind of we hv to predict the thing

# %%
for.EX. :- {round , hard , play } = football or tennis ball
            
           {stores files , Rectangle , small size} = USB or Pendrive

# %% [markdown]
# # IN Machine Learning the hint is :- independent variable

# %% [markdown]
# # AND Predicted thing are :- dependent variable

# %% [markdown]
# # now we using Naive Bayes Classifier

# %% [markdown]
# # for any kind of hint there is an answer with more than 1 variable

# %% [markdown]
# # Naive Bayes Classifier uses the probability to pick the answer with the most probability no.

# %% [markdown]
# # considering a table to predict the acurate variable for given hint

# %% [markdown]
# ![Screenshot%202024-05-01%20081509.png](attachment:Screenshot%202024-05-01%20081509.png)

# %% [markdown]
# firstly we hv to go with columns n row for each variable with most highest probability fits the hint

# %% [markdown]
# ![Screenshot%202024-05-01%20081601.png](attachment:Screenshot%202024-05-01%20081601.png)

# %% [markdown]
# # first we hv done mango n yellow. Now doing mango over long n sweet

# %% [markdown]
# ![Screenshot%202024-05-01%20083204.png](attachment:Screenshot%202024-05-01%20083204.png)

# %%
IN above pic u hv seen the probability we get on mango is multiple of category like yellow , long , sweet

# %% [markdown]
# # now getting the answer of banana n papaya

# %% [markdown]
# ![Screenshot%202024-05-01%20084821.png](attachment:Screenshot%202024-05-01%20084821.png)

# %%
Mango = 0.40 * 0.40 * 0.20
Mango
# Out:
# 0.03200000000000001

# %%
banana = 0.41 * 0.23 * 0.35
banana
# Out:
# 0.03300499999999999

# %%
papaya = 0.28 * 0.33 * 0.38
papaya
# Out:
# 0.035112000000000004

# %% [markdown]
# # THE highest probability hv papaya so the answer is papaya of a given hint

# %% [markdown]
# # PAPAYA = {yellow , long , sweeter}

# %%
This is how Naive Bayes Classifier works in theory

# %% [markdown]
# # In next session will do practically n in desire output with data

# %%
hence we conclude our topic .
